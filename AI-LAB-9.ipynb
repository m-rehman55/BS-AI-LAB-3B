# %%
import pandas  as  pd
import  numpy as  np

# Data Loading/Reading
data_set=pd.read_csv('CrudeOil_Data.csv')

#  Data  Exploration
#  Top  5 rows
print ('Top  5 rows  of the  dataset:')
print ( data_set.head ())

#  Bottom  5 rows
print ('\nBottom  5 rows  of the  dataset:')
print ( data_set. tail())

#   Shape(Rows  and Columns)
number_of_rows  =data_set.shape[0]
number_of_columns=data_set. shape[1]
print ('\nTotal  Rows  and  Columns:')
print ('Total  Rows:',number_of_rows)
print('Total Columns:' ,number_of_columns)

# Check  for Null Values
print ('\nNull values per  column:')
print( data_set.isnull() .sum())

# Data Types
print('\nData types of all  columns:')
print( data_set. dtypes)
# Out:
# Top  5 rows  of the  dataset:
#          Date  Price   Open   High    Low     Vol. Change %
# 0  12/13/2006  61.37  60.97  61.85  60.74  215.43K    0.57%
# 1  12/12/2006  61.02  61.30  62.01  60.65  210.42K   -0.33%
# 2  12/11/2006  61.22  62.21  62.25  61.05  197.11K   -1.31%
# 3  12/08/2006  62.03  62.75  63.65  61.95  217.50K   -0.74%
# 4  12/07/2006  62.49  62.31  62.76  61.55  255.42K    0.48%
#
# Bottom  5 rows  of the  dataset:
#             Date  Price   Open   High    Low    Vol. Change %
# 4995  01/14/1987  19.13  18.97  19.15  18.82  12.18K    1.27%
# 4996  01/13/1987  18.89  18.83  18.95  18.71   8.74K   -0.63%
# 4997  01/12/1987  19.01  19.04  19.20  18.90  11.49K    1.28%
# 4998  01/09/1987  18.77  18.47  18.78  18.42  14.08K    1.08%
# 4999  01/08/1987  18.57  18.41  18.60  18.36  14.60K    1.75%
#
# Total  Rows  and  Columns:
# Total  Rows: 5000
# Total Columns: 7
#
# Null values per  column:
# Date         0
# Price        0
# Open         0
# High         0
# Low          0
# Vol.        11
# Change %     0
# dtype: int64
#
# Data types of all  columns:
# Date         object
# Price       float64
# Open        float64
# High        float64
# Low         float64
# Vol.         object
# Change %     object
# dtype: object
